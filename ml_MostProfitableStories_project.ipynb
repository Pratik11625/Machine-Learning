# %%
import os
os.chdir('D:/py/')

# %%
import pandas as pd
df=pd.read_csv('HollywoodsMostProfitableStories_new.csv')
df
# Out:
#                                     Film    Genre   Lead Studio  \
# 0                        The Dark Knight   Comedy           Fox
# 1                     Mad Max: Fury Road   Comedy           Fox
# 2                              John Wick    Drama   Independent
# 3                           Interstellar    Drama     Universal
# 4                      Blade Runner 2049  Romance   Independent
# ...                                  ...      ...           ...
# 2034                      New Year's Eve  Romance  Warner Bros.
# 2035  Nick and Norah's Infinite Playlist   Comedy          Sony
# 2036                     No Reservations   Comedy           NaN
# 2037                   Not Easily Broken    Drama   Independent
# 2038                             One Day  Romance   Independent
#
#       Audience  score %  Profitability  Rotten Tomatoes %  Worldwide Gross  \
# 0                  65.0           26.0               90.0             58.0
# ...

# %% [markdown]
# # eda

# %%
df.isna().sum()
# Out:
# Film                  0
# Genre                 0
# Lead Studio          28
# Audience  score %     0
# Profitability         0
# Rotten Tomatoes %     0
# Worldwide Gross       0
# Year                  0
# dtype: int64

# %%
df.nunique()
# Out:
# Film                 233
# Genre                  6
# Lead Studio           40
# Audience  score %     28
# Profitability         21
# Rotten Tomatoes %     68
# Worldwide Gross       48
# Year                   5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2039 entries, 0 to 2038
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               2039 non-null   object
#  1   Genre              2039 non-null   object
#  2   Lead Studio        2011 non-null   object
#  3   Audience  score %  2039 non-null   float64
#  4   Profitability      2039 non-null   float64
#  5   Rotten Tomatoes %  2039 non-null   float64
#  6   Worldwide Gross    2039 non-null   float64
#  7   Year               2039 non-null   int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 127.6+ KB

# %%
df.describe(include='all')
# Out:
#                      Film   Genre  Lead Studio  Audience  score %  \
# count                2039    2039         2011        2039.000000
# unique                233       6           40                NaN
# top     Letters to Juliet  Comedy  Independent                NaN
# freq                   22    1132          522                NaN
# mean                  NaN     NaN          NaN          71.260912
# std                   NaN     NaN          NaN           7.932158
# min                   NaN     NaN          NaN          58.000000
# 25%                   NaN     NaN          NaN          64.000000
# 50%                   NaN     NaN          NaN          71.000000
# 75%                   NaN     NaN          NaN          78.000000
# max                   NaN     NaN          NaN          85.000000
#
#         Profitability  Rotten Tomatoes %  Worldwide Gross         Year
# count     2039.000000        2039.000000      2039.000000  2039.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Ankita\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
plt.figure(figsize=(12,8))
df.corr().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=df['Audience  score %'],y=df['Rotten Tomatoes %'])
# Out:
# <AxesSubplot:xlabel='Audience  score %', ylabel='Rotten Tomatoes %'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
df['Audience  score %']=df['Audience  score %'].fillna(df['Audience  score %'].mean())

# %% [markdown]
# # define x and y

# %%
x=df.drop(['Audience  score %'],axis=1)
y=df['Audience  score %']

# %%
x
# Out:
#                                     Film    Genre   Lead Studio  \
# 0                        The Dark Knight   Comedy           Fox
# 1                     Mad Max: Fury Road   Comedy           Fox
# 2                              John Wick    Drama   Independent
# 3                           Interstellar    Drama     Universal
# 4                      Blade Runner 2049  Romance   Independent
# ...                                  ...      ...           ...
# 2034                      New Year's Eve  Romance  Warner Bros.
# 2035  Nick and Norah's Infinite Playlist   Comedy          Sony
# 2036                     No Reservations   Comedy           NaN
# 2037                   Not Easily Broken    Drama   Independent
# 2038                             One Day  Romance   Independent
#
#       Profitability  Rotten Tomatoes %  Worldwide Gross  Year
# 0              26.0               90.0             58.0  2008
# 1              27.0               86.0             70.0  2009
# ...

# %%
y
# Out:
# 0       65.0
# 1       73.0
# 2       75.0
# 3       76.0
# 4       74.0
#         ...
# 2034    59.0
# 2035    65.0
# 2036    71.0
# 2037    66.0
# 2038    75.0
# Name: Audience  score %, Length: 2039, dtype: float64

# %%
y.isna().sum()
# Out:
# 0

# %%
y.mode()
# Out:
# 0    71.0
# dtype: float64

# %% [markdown]
# # preprocsing pipeline

# %%
cat=[]
con=[]
for i in x.columns:
    if x[i].dtypes=='object':
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['Film', 'Genre', 'Lead Studio']

# %%
con
# Out:
# ['Profitability', 'Rotten Tomatoes %', 'Worldwide Gross', 'Year']

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
cat_pip= Pipeline(steps=[('imputer',SimpleImputer(strategy='most_frequent')),('encoder',OrdinalEncoder())])
print('cat_pip',cat_pip)
print('--'*50)
con_pip= Pipeline(steps=[('imputer',SimpleImputer(strategy='median')),('scaler',StandardScaler())])
print('con_pip',con_pip)
print('--'*50)
pre=ColumnTransformer([('cat_pip',cat_pip,cat),('con_pip',con_pip,con)])
pre
# Out:
# cat_pip Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder', OrdinalEncoder())])
# ----------------------------------------------------------------------------------------------------
# con_pip Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler())])
# ----------------------------------------------------------------------------------------------------
# ColumnTransformer(transformers=[('cat_pip',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder())]),
#                                  ['Film', 'Genre', 'Lead Studio']),
#                                 ('con_pip',
#                                  Pipeline(steps=[('imputer',
# ...

# %%
x_feat=pd.DataFrame(pre.fit_transform(x),columns=pre.get_feature_names_out())
x_feat
# Out:
#       cat_pip__Film  cat_pip__Genre  cat_pip__Lead Studio  \
# 0             162.0             2.0                  30.0
# 1              97.0             2.0                  30.0
# 2              83.0             3.0                  31.0
# 3              80.0             3.0                  38.0
# 4              41.0             5.0                  31.0
# ...             ...             ...                   ...
# 2034          108.0             5.0                  39.0
# 2035          109.0             2.0                  35.0
# 2036          111.0             2.0                  31.0
# 2037          112.0             3.0                  31.0
# 2038          113.0             5.0                  31.0
#
#       con_pip__Profitability  con_pip__Rotten Tomatoes %  \
# 0                   0.170343                    1.441891
# 1                   0.337328                    1.240682
# 2                   1.673210                   -0.368990
# ...

# %% [markdown]
# # split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_feat,y,test_size=10,random_state=19)

# %%
x_train
# Out:
#       cat_pip__Film  cat_pip__Genre  cat_pip__Lead Studio  \
# 1082           54.0             3.0                  36.0
# 717           152.0             1.0                  29.0
# 1494          121.0             2.0                  39.0
# 249            96.0             3.0                  38.0
# 1613          212.0             3.0                  36.0
# ...             ...             ...                   ...
# 936           132.0             2.0                  39.0
# 1378          156.0             3.0                  36.0
# 757            81.0             2.0                  38.0
# 622           100.0             2.0                  30.0
# 1629            0.0             2.0                  30.0
#
#       con_pip__Profitability  con_pip__Rotten Tomatoes %  \
# 1082               -0.330613                   -0.570199
# 717                -1.165539                    0.536450
# 1494                1.673210                   -0.218083
# ...

# %%
x_test
# Out:
#       cat_pip__Film  cat_pip__Genre  cat_pip__Lead Studio  \
# 363           223.0             1.0                  29.0
# 455            66.0             1.0                  29.0
# 1090          171.0             3.0                  34.0
# 1525          120.0             3.0                  31.0
# 1534          166.0             3.0                  34.0
# 37            150.0             2.0                  35.0
# 1384          185.0             2.0                  28.0
# 1991          223.0             1.0                  29.0
# 172            92.0             2.0                  39.0
# 1801           93.0             2.0                  31.0
#
#       con_pip__Profitability  con_pip__Rotten Tomatoes %  \
# 363                -1.165539                   -0.570199
# 455                 0.838284                    0.637055
# 1090                0.838284                   -0.368990
# 1525                1.506225                    1.240682
# ...

# %% [markdown]
# # model

# %% [markdown]
# from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import AdaBoostClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.svm import SVC
# from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# lo=LogisticRegression()
# dtc=DecisionTreeClassifier()
# ada=AdaBoostClassifier()
# rfc=RandomForestClassifier()
# svc=SVC()
# knc=KNeighborsClassifier()

# %% [markdown]
# list1=[lo,dtc,ada,rfc,svc,knc]

# %% [markdown]
# # evalution

# %% [markdown]
# from sklearn.metrics import accuracy_score,f1_score

# %% [markdown]
# for i in list1:
#     i.fit(x_train,y_train)
#     i.fit(x_test,y_test)
#
#     y_pred_train=i.predict(x_train)
#     y_pred_test=i.predict(x_test)
#
#     acc1=accuracy_score(y_pred_train,y_train)
#     f11=f1_score(y_pred_train,y_train)
#     print('acc',acc1)
#     print('f1',f11)
#     print('--'*50)
#
#     acc2=accuracy_score(y_pred_test,y_test)
#     f12=f1_score(y_pred_test,y_test)
#     print('acc',acc2)
#     print('f1',f12)

# %% [markdown]
# # model 1

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
y_pred_train1=lr.predict(x_train)
y_pred_train1
# Out:
# array([71.46421168, 71.28005494, 71.3197519 , ..., 71.15918045,
#        70.94822962, 71.04854435])

# %%
r21=r2_score(y_pred_train1,y_train)
r21
# Out:
# -499.5952087136641

# %%
y_pred_test1=lr.predict(x_test)
y_pred_test1
# Out:
# array([71.31902703, 70.85412599, 71.49762768, 71.11309122, 71.45772826,
#        70.45635791, 71.79143643, 71.36151633, 70.86742372, 71.62761522])

# %%
r22=r2_score(y_pred_test1,y_test)
r22
# Out:
# -239.60476299406

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
la=Lasso()

# %%
la.fit(x_train,y_train)
# Out:
# Lasso()

# %% [markdown]
# ## evalution

# %%
y_pred_train11=la.predict(x_train)
y_pred_train11
# Out:
# array([71.12541263, 71.28747745, 71.23621205, ..., 71.17006314,
#        71.20148387, 71.03611161])

# %%
r23=r2_score(y_pred_train11,y_train)
r23
# Out:
# -5984.110373631836

# %%
y_pred_test11=la.predict(x_test)
y_pred_test11
# Out:
# array([71.40489176, 71.1452573 , 71.31889818, 71.23455833, 71.31062957,
#        71.28417001, 71.3420503 , 71.40489176, 71.18825409, 71.18990782])

# %%
r24=r2_score(y_pred_test11,y_test)
r24
# Out:
# -4830.797125011959

# %%
la=Lasso()

# %%
la.fit(x_train,y_train)
# Out:
# Lasso()

# %% [markdown]
# ## evalution

# %%
y_pred_train11=la.predict(x_train)
y_pred_train11
# Out:
# array([71.12541263, 71.28747745, 71.23621205, ..., 71.17006314,
#        71.20148387, 71.03611161])

# %%
r23=r2_score(y_pred_train11,y_train)
r23
# Out:
# -5984.110373631836

# %%
y_pred_test11=la.predict(x_test)
y_pred_test11
# Out:
# array([71.40489176, 71.1452573 , 71.31889818, 71.23455833, 71.31062957,
#        71.28417001, 71.3420503 , 71.40489176, 71.18825409, 71.18990782])

# %%
r26=r2_score(y_pred_test11,y_test)
r26
# Out:
# -4830.797125011959

# %%
ri=Ridge()
ri.fit(x_train,y_train)

## evalution

y_pred_train22=ri.predict(x_train)
y_pred_train22

r25=r2_score(y_pred_train22,y_train)
print('r2',r25)
print('--'*56)

y_pred_test22=ri.predict(x_test)
y_pred_test22

r26=r2_score(y_pred_test22,y_test)
r26
# Out:
# r2 -500.0160037442001
# ----------------------------------------------------------------------------------------------------------------
# -239.84309216127787

# %% [markdown]
# # hyperparamter

# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# %%
gride= {
    'alpha': np.arange(0.1,2,0.01)
}

# %%
rs=RandomizedSearchCV(la,param_distributions=gride,cv=2)
rs
# Out:
# RandomizedSearchCV(cv=2, estimator=Lasso(),
#                    param_distributions={'alpha': array([0.1 , 0.11, 0.12, 0.13, 0.14, 0.15, 0.16, 0.17, 0.18, 0.19, 0.2 ,
#        0.21, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.29, 0.3 , 0.31,
#        0.32, 0.33, 0.34, 0.35, 0.36, 0.37, 0.38, 0.39, 0.4 , 0.41, 0.42,
#        0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.5 , 0.51, 0.52, 0.53,
#        0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.6 , 0.61, 0.62, 0.63, 0.64,
#        0.6...
#        1.2 , 1.21, 1.22, 1.23, 1.24, 1.25, 1.26, 1.27, 1.28, 1.29, 1.3 ,
#        1.31, 1.32, 1.33, 1.34, 1.35, 1.36, 1.37, 1.38, 1.39, 1.4 , 1.41,
#        1.42, 1.43, 1.44, 1.45, 1.46, 1.47, 1.48, 1.49, 1.5 , 1.51, 1.52,
#        1.53, 1.54, 1.55, 1.56, 1.57, 1.58, 1.59, 1.6 , 1.61, 1.62, 1.63,
#        1.64, 1.65, 1.66, 1.67, 1.68, 1.69, 1.7 , 1.71, 1.72, 1.73, 1.74,
#        1.75, 1.76, 1.77, 1.78, 1.79, 1.8 , 1.81, 1.82, 1.83, 1.84, 1.85,
# ...

# %%
rs.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=2, estimator=Lasso(),
#                    param_distributions={'alpha': array([0.1 , 0.11, 0.12, 0.13, 0.14, 0.15, 0.16, 0.17, 0.18, 0.19, 0.2 ,
#        0.21, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.29, 0.3 , 0.31,
#        0.32, 0.33, 0.34, 0.35, 0.36, 0.37, 0.38, 0.39, 0.4 , 0.41, 0.42,
#        0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.5 , 0.51, 0.52, 0.53,
#        0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.6 , 0.61, 0.62, 0.63, 0.64,
#        0.6...
#        1.2 , 1.21, 1.22, 1.23, 1.24, 1.25, 1.26, 1.27, 1.28, 1.29, 1.3 ,
#        1.31, 1.32, 1.33, 1.34, 1.35, 1.36, 1.37, 1.38, 1.39, 1.4 , 1.41,
#        1.42, 1.43, 1.44, 1.45, 1.46, 1.47, 1.48, 1.49, 1.5 , 1.51, 1.52,
#        1.53, 1.54, 1.55, 1.56, 1.57, 1.58, 1.59, 1.6 , 1.61, 1.62, 1.63,
#        1.64, 1.65, 1.66, 1.67, 1.68, 1.69, 1.7 , 1.71, 1.72, 1.73, 1.74,
#        1.75, 1.76, 1.77, 1.78, 1.79, 1.8 , 1.81, 1.82, 1.83, 1.84, 1.85,
# ...

# %%
rs.best_params_
# Out:
# {'alpha': 0.17999999999999997}

# %%
la1=rs.best_estimator_
la1
# Out:
# Lasso(alpha=0.17999999999999997)

# %%
y_pred_train33=la1.predict(x_train)
y_pred_train33

r28=r2_score(y_pred_train33,y_train)
print('r2',r28)
print('--'*56)

y_pred_test33=la1.predict(x_test)
y_pred_test33

r29=r2_score(y_pred_test33,y_test)
r29
# Out:
# r2 -2907.549061668618
# ----------------------------------------------------------------------------------------------------------------
# -1884.697183778718

# %%
df1=pd.read_csv('HollywoodsMostProfitableStories.csv')
df1
# Out:
#                                   Film    Genre            Lead Studio  \
# 0                 (500) Days of Summer   Comedy                    Fox
# 1                   A Dangerous Method    Drama            Independent
# 2                        A Serious Man    Drama              Universal
# 3                  Across the Universe  Romance            Independent
# 4                            Beginners   Comedy            Independent
# ..                                 ...      ...                    ...
# 69  You Will Meet a Tall Dark Stranger   Comedy            Independent
# 70                     Youth in Revolt   Comedy  The Weinstein Company
# 71          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 72                                 NaN      NaN                    NaN
# 73                                 NaN      NaN                    NaN
#
#     Audience  score %  Profitability  Rotten Tomatoes %  Worldwide Gross  \
# ...

# %%
x_un=pd.DataFrame(pre.transform(df1),columns=pre.get_feature_names_out())
x_un
# Out:
#     cat_pip__Film  cat_pip__Genre  cat_pip__Lead Studio  \
# 0             0.0             2.0                  30.0
# 1            30.0             3.0                  31.0
# 2            32.0             3.0                  38.0
# 3            34.0             5.0                  31.0
# 4            39.0             2.0                  31.0
# ..            ...             ...                   ...
# 69          230.0             2.0                  31.0
# 70          231.0             2.0                  37.0
# 71          232.0             5.0                  37.0
# 72           87.0             2.0                  31.0
# 73           87.0             2.0                  31.0
#
#     con_pip__Profitability  con_pip__Rotten Tomatoes %  \
# 0                -2.819361                    1.290984
# 1                -4.096357                    0.888566
# 2                -3.439401                    1.391588
# 3                -4.062299                   -0.368990
# ...

# %%
y_un=la.predict(x_un)
y_un
# Out:
# array([71.03611161, 71.08572329, 71.08903073, 71.09233818, 71.10060679,
#        71.12045146, 71.12375891, 71.13368125, 71.13864241, 71.14194986,
#        71.1452573 , 71.14691103, 71.15021847, 71.15848709, 71.16179453,
#        71.16344825, 71.17006314, 71.17171687, 71.17667803, 71.17833176,
#        71.17998548, 71.18494665, 71.18660037, 71.18825409, 71.18990782,
#        71.19321526, 71.19486898, 71.19817643, 71.19983015, 71.20148387,
#        71.20479132, 71.20644504, 71.20809876, 71.21140621, 71.21305993,
#        71.21471366, 71.21636738, 71.21967482, 71.22132855, 71.22298227,
#        71.22628971, 71.22794344, 71.22959716, 71.23125088, 71.23455833,
#        71.23786577, 71.24613439, 71.28086256, 71.28251628, 71.28747745,
#        71.2907849 , 71.30236096, 71.31062957, 71.32551307, 71.33378169,
#        71.36024125, 71.38339337, 71.38670081, 71.38835453, 71.39827687,
#        71.39993059, 71.40158432, 71.40323804, 71.40654548, 71.40819921,
# ...

# %%
df3=df1[['Audience  score %']]
df3
# Out:
#     Audience  score %
# 0                81.0
# 1                89.0
# 2                64.0
# 3                84.0
# 4                80.0
# ..                ...
# 69               35.0
# 70               52.0
# 71               70.0
# 72                NaN
# 73                NaN
#
# [74 rows x 1 columns]

# %%
df3['Audience score % predict']=y_un
# Out:
# <ipython-input-69-65a9645ca18b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Audience score % predict']=y_un

# %%
df3
# Out:
#     Audience  score %  Audience score % predict
# 0                81.0                 71.036112
# 1                89.0                 71.085723
# 2                64.0                 71.089031
# 3                84.0                 71.092338
# 4                80.0                 71.100607
# ..                ...                       ...
# 69               35.0                 71.416468
# 70               52.0                 71.418122
# 71               70.0                 71.419775
# 72                NaN                 71.179985
# 73                NaN                 71.179985
#
# [74 rows x 2 columns]
