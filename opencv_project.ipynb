# %% [raw]
# converting the RGB images to GRAY scale images.
#
# Converting RGB images to grayscale images is a common preprocessing step in
# image processing and computer vision tasks. It involves converting each pixel of
# the RGB image into a single intensity value representing the grayscale version of the image.

# %%
# !pip install opencv
# Out:
# ERROR: Could not find a version that satisfies the requirement opencv
# ERROR: No matching distribution found for opencv

# %%
import cv2

# %%
A= cv2.imread('.../SUNSET.jpg')

# %%
A
# Out:
# array([[[51, 34, 37],
#         [48, 31, 34],
#         [47, 30, 33],
#         ...,
#         [27, 17, 17],
#         [27, 17, 17],
#         [27, 17, 17]],
#
#        [[49, 32, 35],
#         [46, 29, 32],
#         [46, 29, 32],
#         ...,
#         [27, 17, 17],
#         [27, 17, 17],
#         [27, 17, 17]],
#
#        [[46, 29, 32],
#         [45, 28, 31],
#         [45, 28, 31],
#         ...,
#         [27, 17, 17],
#         [27, 17, 17],
#         [27, 17, 17]],
#
#        ...,
#
#        [[18, 16, 16],
#         [18, 16, 16],
#         [18, 16, 16],
#         ...,
#         [18, 16, 16],
#         [18, 16, 16],
#         [18, 16, 16]],
#
#        [[18, 16, 16],
#         [18, 16, 16],
#         [18, 16, 16],
#         ...,
#         [18, 16, 16],
#         [18, 16, 16],
#         [18, 16, 16]],
#
#        [[18, 16, 16],
#         [18, 16, 16],
#         [18, 16, 16],
#         ...,
#         [18, 16, 16],
#         [18, 16, 16],
#         [18, 16, 16]]], dtype=uint8)

# %%
A.shape
# Out:
# (600, 1068, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(A)

# %%
B=cv2.cvtColor(A,cv2.COLOR_BGR2RGB)

# %%
B
# Out:
# array([[[37, 34, 51],
#         [34, 31, 48],
#         [33, 30, 47],
#         ...,
#         [17, 17, 27],
#         [17, 17, 27],
#         [17, 17, 27]],
#
#        [[35, 32, 49],
#         [32, 29, 46],
#         [32, 29, 46],
#         ...,
#         [17, 17, 27],
#         [17, 17, 27],
#         [17, 17, 27]],
#
#        [[32, 29, 46],
#         [31, 28, 45],
#         [31, 28, 45],
#         ...,
#         [17, 17, 27],
#         [17, 17, 27],
#         [17, 17, 27]],
#
#        ...,
#
#        [[16, 16, 18],
#         [16, 16, 18],
#         [16, 16, 18],
#         ...,
#         [16, 16, 18],
#         [16, 16, 18],
#         [16, 16, 18]],
#
#        [[16, 16, 18],
#         [16, 16, 18],
#         [16, 16, 18],
#         ...,
#         [16, 16, 18],
#         [16, 16, 18],
#         [16, 16, 18]],
#
#        [[16, 16, 18],
#         [16, 16, 18],
#         [16, 16, 18],
#         ...,
#         [16, 16, 18],
#         [16, 16, 18],
#         [16, 16, 18]]], dtype=uint8)

# %%
plt.imshow(B)

# %%
c= cv2.imread('../SUNSET.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(c,cmap='gray')
